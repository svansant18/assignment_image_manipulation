# %% [markdown]
# **This notebook is a demo project on how to utilise the image manipulation utils from /scripts/utils.py for the image manipulation assigment.**

# %% [markdown]
# Importing required python libraries

# %%
from PIL import Image
import numpy as np
import sys
import os
import random

sys.path.append('../scripts')
import image_manipulation

# %% [markdown]
# Loading the augurk_image.jpg image from the images folder, feel free to replace this image with any other image of your choice

# %%
fp = os.path.join(os.getcwd(), '../images','augurk_image.jpg')
np_image = np.array(Image.open(fp), dtype="int32")

# %% [markdown]
# **Initial recreation of the images from the assignment.**

# %% [markdown]
# **Image 1: Image tiles (no manipulations)**
#
# ![image.png](attachment:8bd98666-ce62-443c-bf43-00d2da00f889.png)
